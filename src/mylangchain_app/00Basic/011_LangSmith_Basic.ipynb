# %% [markdown]
# #### LangSmith 기본 예제

# %% [markdown]
# ##### 1) 라이브러리 설치

# %%
# poetry add langsmith

# %% [markdown]
# ##### 2) OpenAI 인증키 설정

# %%
import os
from dotenv import load_dotenv
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv(dotenv_path='../.env')

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_t

# %% [markdown]
# ##### LangSmith와 LangChain을 활용한 기본 로깅 예제

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langsmith import traceable

# LangSmith API Key 설정
os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING")  # LangSmith 활성화
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")  # API Key 불러오기
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")   # 프로젝트 이름 설정
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")   # EndPoint 설정

# LLM 모델 설정 (OpenAI 사용)
#llm = ChatOpenAI(model="gpt-3.5-turbo")
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# LangSmith로 실행 추적
@traceable(run_type="chain", name="Simple_Chain")
def ask_question(question: str):

    # 개별 메시지 템플릿 정의
    system_message = SystemMessagePromptTemplate.from_template(
        "당신은 유용한 AI 비서입니다."
    )
    user_message = HumanMessagePromptTemplate.from_template(
        "{question}"
    )

    chat_prompt = ChatPromptTemplate.from_messages([
        system_message,
        user_message,
    ])
    
    messages = chat_prompt.format_messages(question=question)
    response = llm.invoke(messages)

    return response.content

# 테스트 실행
question = "LangGraph와 LangChain의 차이점은 무엇인가요?"
answer = ask_question(question)

# 결과 출력
print("\n🔹 [AI 답변]:")
print(answer)
# Out:
# 🔹 [AI 답변]:
# LangGraph와 LangChain은 모두 언어 모델을 활용하여 애플리케이션을 구축하기 위한 라이브러리이지만, 다른 목적과 디자인 철학을 가지고 있습니다.
#
# LangChain은 언어 모델을 사용하여 애플리케이션을 구축하기 위한 통합 플랫폼을 제공하는 라이브러리입니다. LangChain은 언어 모델을 호출하고, 입력과 출력을 처리하며, 다양한 도구와 데이터 소스를 통합하는 기능을 제공합니다. LangChain은 개발자가 언어 모델을 쉽게 통합하고, 애플리케이션에 언어 모델의 기능을 활용할 수 있도록 지원합니다.
#
# LangGraph는 LangChain의 하위 라이브러리로서, 여러 작업과 단계를 그래프 형태로 정의하고 실행할 수 있도록 지원하는 라이브러리입니다. LangGraph는 LangChain의 핵심 개념인 에이전트, 액션, 워크플로우를 그래프 형태로 정의하고 실행할 수 있도록 하며, 복잡한 워크플로우를 관리하고, 에이전트와 액션 간의 관계를 정의하는 데 사용됩니다.
#
# 즉, LangChain은 언어 모델을 활용한 애플리케이션 개발을 위한 통합 플랫폼을 제공하며, LangGraph는 LangChain을 기반으로 하여 워크플로우와 에이전트를 그래프 형태로 정의하고 실행하는 라이브러리입니다. LangGraph는 LangChain의 확장 라이브러리로서, LangChain의 기능을 확장하고, 보다 복잡한 애플리케이션을 개발할 수 있도록 지원합니다.
#
# LangChain과 LangGraph는 모두 언어 모델을 활용하여 애플리케이션을 구축하기 위한 라이브러리이지만, LangChain은 통합 플랫폼을 제공하고, LangGraph는 워크플로우와 에이전트를 그래프 형태로 정의하고 실행하는 라이브러리입니다.
