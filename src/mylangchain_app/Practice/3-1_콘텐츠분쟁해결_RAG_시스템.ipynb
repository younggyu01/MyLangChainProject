# %% [markdown]
# ## 문제 3-1 :  콘텐츠분쟁해결 RAG 시스템 - 간단 실습 가이드
# ### 콘텐츠분쟁해결 사례집을 활용한 법률 자문 RAG 시스템을 순차적으로 구축하는 실습입니다.
#
# ## 0단계: 문서 로드
# ### loader = PyPDFLoader('../data/콘텐츠분쟁해결_사례.pdf')
#
# ## 1단계: 문서 분할 설정
# ### pythontext_splitter = RecursiveCharacterTextSplitter(
# ###     chunk_size=1500,        #  법률 사례는 1200-1800자 권장
# ###     chunk_overlap=300,      #  사례 맥락 보존을 위해 200-400자
# ###     separators=[
# ###         "\n【사건개요】",     #  법률 문서 섹션 구분자
# ###         "\n【쟁점사항】",     #  쟁점 부분 구분
# ###         "\n【처리경위】",     #  처리 과정 구분
# ###         "\n【처리결과】",     #  결과 부분 구분
# ###         "\n■", "\n\n", "\n", ".", " ", ""
# ###     ]
# ### )
#
# ## 2단계: 임베딩 모델 설정
# ### pythonembeddings = UpstageEmbeddings(model="solar-embedding-1-large")
#
# ## 3단계: 검색기 설정
# ### pythonretriever = vectorstore.as_retriever(
# ###     search_type="similarity",        #  또는 "mmr" (다양성 고려시)
# ###     search_kwargs={"k": 5}          #  상위 5개 관련 사례 검색
# ### )
#
# ## 4단계: LLM 설정
# ### pythonllm = ChatUpstage(
# ###         model="solar-pro",
# ###         base_url="https://api.upstage.ai/v1",
# ###         temperature=0.2
# ###     )
#
# ## 5단계: 법률 자문 프롬프트 작성
# ### pythonprompt_template = """
# ### 당신은 콘텐츠 분야 전문 법률 자문가입니다.
# ### 아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.
#
# ### 관련 분쟁사례:
# ### {context}
#
# ### 상담 내용: {question}
#
# ### 답변 가이드라인:
# ### 1. 제시된 사례들을 근거로 답변하세요                    # 사례 기반 답변
# ### 2. 관련 법령이나 조항이 있다면 명시하세요               # 법적 근거 제시
# ### 3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요    # 판례 참조
# ### 4. 실무적 해결방안을 단계별로 제시하세요               #  실무 가이드
# ### 5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요  #  한계 인정
#
# ### 전문 법률 조언:"""
#
# ## 6단계: QA 체인 생성
# ### pythonqa_chain = RetrievalQA.from_chain_type(
# ###     llm=llm,                        #  위에서 설정한 LLM
# ###     chain_type="stuff",             #  문서들을 하나로 합쳐서 처리
# ###     retriever=retriever,            #  위에서 설정한 검색기
# ###     chain_type_kwargs={"prompt": prompt},  #  법률 자문 프롬프트
# ###     return_source_documents=True    #  참조 문서도 함께 반환
# ### )
#
# ## 7단계: 테스트 질문 작성
# ### pythontest_questions = [
# ###     "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
# ###     "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
# ###     "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
# ###     "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
# ###     "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
# ### ]
#
# ## 8단계: 분쟁 유형 분류 함수 ( 선택 )
# ### def classify_dispute_type(query):
# ###     game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
# ###     elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
# ###     web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
#
# ###     query_lower = query.lower()
#
# ###     if any(keyword in query_lower for keyword in game_keywords):
# ###         return "게임"
# ###     elif any(keyword in query_lower for keyword in elearning_keywords):
# ###         return "이러닝"
# ###     elif any(keyword in query_lower for keyword in web_keywords):
# ###         return "웹콘텐츠"
# ###     else:
# ###         return "기타"
#
# ### 프롬프트 기본 템플릿:
# ### python# 기본 법률 자문 프롬프트 (5분 만에 완성)
# ### prompt_template = """당신은 콘텐츠 분야 전문 법률 자문사입니다.
#
# ### 관련 분쟁사례: {context}
# ### 상담 내용: {question}
#
# ## 답변 가이드라인:
# ### 1. 사례를 근거로 답변하세요.
# ### 2. 관련 법령을 명시하세요.
# ### 3. 단계별 해결방안을 제시하세요.
# ### 4. 유사 사례를 참조하세요.
# ### 5. 없는 정보는 "확인할 수 없습니다"라고 하세요.

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain.chains import RetrievalQA
from langchain_core.prompts import PromptTemplate

# %%
load_dotenv()

UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
# Out:
# O6

# %%
USE_UPSTAGE = False
embeddings = None
llm = None

try:
    from langchain_upstage import UpstageEmbeddings, ChatUpstage
    upstage_key = os.getenv("UPSTAGE_API_KEY")
    if not upstage_key:
        raise RuntimeError("UPSTAGE_API_KEY not set")
    embeddings = UpstageEmbeddings(model="solar-embedding-1-large", api_key=upstage_key)
    llm = ChatUpstage(model="solar-pro", api_key=upstage_key, base_url="https://api.upstage.ai/v1", temperature=0.2)
    USE_UPSTAGE = True
    print("Upstage 임베딩,LLM 사용")
except Exception as e:
    print(f"Upstage 사용 불가 -> 폴백: HF 임베딩 + Groq LLM ({e})")
    from langchain_huggingface import HuggingFaceEmbeddings
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    from langchain_openai import ChatOpenAI
    groq_key = os.getenv("GROQ_API_KEY") or os.getenv("OPENAI_API_KEY")
    llm = ChatOpenAI(api_key=groq_key, base_url="https://api.groq.com/openai/v1", model="openai/gpt-oss-120b", temperature=0.2)
    print("HF 임베딩 + Groq LLM 사용")
# Out:
# Upstage 임베딩,LLM 사용

# %%
PDF_NAME = "콘텐츠분쟁해결_사례.pdf"
candidate = Path("../data") / PDF_NAME
pdf_path = None

if candidate.is_file():
    pdf_path = candidate.resolve()
else:
    hits = list(Path.cwd().resolve().rglob(PDF_NAME))
    if hits:
        pdf_path = hits[0].resolve()

if not pdf_path:
    raise FileNotFoundError("콘텐츠분쟁해결_사례.pdf 파일을 찾을 수 없습니다. 경로를 확인하세요.")

print("[PDF]", pdf_path)

loader = PyPDFLoader(str(pdf_path))
docs = loader.load()
print("총 페이지 수:", len(docs))
# Out:
# [PDF] C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
# 총 페이지 수: 109

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=300,
    separators=[
        "\n【사건개요】",
        "\n【쟁점사항】",
        "\n【처리경위】",
        "\n【처리결과】",
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)
splits = text_splitter.split_documents(docs)
print("생성된 청크 수:", len(splits))
if not splits:
    raise RuntimeError("분할된 청크가 없습니다. PDF 또는 분할 설정을 확인하세요.")
# Out:
# 생성된 청크 수: 104

# %%
PERSIST_DIR = str((Path.cwd() / "chroma_law_db").resolve())
vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embeddings,
    persist_directory=PERSIST_DIR,
    collection_name="kocdac_cases"
)

retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)
print("벡터DB 준비 완료 →", PERSIST_DIR)
# Out:
# 벡터DB 준비 완료 → C:\mylangchain\mylangchain-app\src\mylangchain_app\Practice\chroma_law_db

# %%
prompt_text = """너는 콘텐츠 분야 전문 법률 자문가입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요
2. 관련 법령이나 조항이 있다면 명시하세요
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요
4. 실무적 해결방안을 단계별로 제시하세요
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요

전문 법률 조언:"""

prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_text
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
print("QA 체인 준비 완료")
# Out:
# QA 체인 준비 완료

# %%
test_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

for i, q in enumerate(test_questions, 1):
    print("\n" + "="*80)
    print(f"[Q{i}] {q}")
    result = qa_chain.invoke({"query": q})
    print("\n[답변]\n", result["result"].strip())
    print("\n[참조 출처]")
    for idx, d in enumerate(result.get("source_documents", []), 1):
        meta = d.metadata or {}
        page = meta.get("page", meta.get("source", "N/A"))
        print(f"  - {idx}) page={page}, source={meta.get('source', 'PDF')}")
# Out:
# ================================================================================
# [Q1] 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#
# [답변]
#  ### 전문 법률 조언: 온라인 게임 시스템 오류로 인한 아이템 손실 시 법적 대응 방안
#
# #### 1. **사례 분석 및 쟁점 정리**
# 제시된 사례(2006년, 2009년 시스템 오류 사례)에 따르면, 게임회사는 다음 사유로 복구를 거부한 것으로 확인됩니다:
# - **계정 명의 불일치**: 게임회사가 현금거래 및 계정 공유를 금지하는 약관을 근거로, 실소유주라도 명의자가 아닌 경우 복구를 거부(2006년 사례).
# - **시스템 오류 입증 부족**: 다른 이용자에게 동일한 오류가 보고되지 않았거나, 이용 내역상 문제가 없어 게임회사의 과실을 인정하기 어려운 경우(2009년 사례).
#
# #### 2. **관련 법령 및 약관 검토**
# - **전자상거래법 제17조(계약 해제·해지 및 대금 환급)**
#   - 게임회사가 서비스 제공 과정에서 발생한 시스템 오류로 인해 이용자가 손해를 입은 경우, 민법상 **채무불이행** 또는 **불법행위** 책임(민법 제390조, 제750조)이 발생할 수 있습니다.
#   - 다만, 게임회사가 **"약관에서 시스템 오류로 인한 책임을 명시적으로 배제"**한 경우, 해당 약관이 **약관의 규제에 관한 법률 제6조(불공정약관 무효)**에 따라 무효인지 여부가 쟁점이 됩니다.
#     - 예: "모든 시스템 오류에 대한 책임을 지지 않는다"는 조항은 불공정할 수 있음.
#
# - **게임산업진흥에 관한 법률 제12조(게임물의 내용 및 운영 기준)**
#   - 게임회사는 이용자에게 **공정한 서비스 제공 의무**가 있으며, 시스템 오류 시 합리적인 조치를 취해야 합니다.
#
# #### 3. **실무적 해결 방안 (단계별 접근)**
# **(1) 증거 수집 및 보존**
# - **시스템 오류 증거**: 게임 내 로그, 스크린샷, 고객센터 문의 기록, 오류 발생 시점의 접속 기록 등을 확보합니다.
# - **계정 소유권 증명**: 명의자와 실소유주가 다른 경우, 현금거래 내역(계좌이체 증빙, 대화 기록) 또는 계정 양도 합의서를 준비합니다.
#   - *※ 단, 게임회사가 계정 공유를 금지하는 경우, 약관에 따라 복구가 어려울 수 있음(2006년 사례 참조).*
#
# **(2) 게임회사에 공식 이의제기**
# - **고객센터 또는 분쟁조정 신청**:
#   - 시스템 오류 발생 일시, 아이템 손실 내용, 복구 요청 사항을 명시한 문서를 제출합니다.
#   - 2009년 사례와 같이 게임회사가 "다른 이용자에게 동일한 오류가 없었다"는 주장을 할 경우, **동일 기간 오류 신고 건수**를 정보공개청구로 요청할 수 있습니다.
#
# **(3) 한국소비자원에 분쟁조정 신청**
# - **조정 신청 절차**:
#   - 한국소비자원 홈페이지 또는 지역 소비센터에서 온라인/오프라인 신청 가능.
#   - 2006년 사례와 같이 계정 명의 문제가 있는 경우, **실소유주임을 입증할 추가 증거**를 제출해야 합니다.
#   - 게임회사가 시스템 오류를 부인하는 경우, **제3자 감정(예: 게임 로그 분석)**을 요청할 수 있습니다.
#
# **(4) 소송 제기 (최후 수단)**
# - **민사소송**:
#   - 게임회사의 **채무불이행** 또는 **불법행위**를 이유로 손해배상 청구 가능.
#   - 단, 소송 비용과 시간을 고려할 때, **아이템의 금전적 가치가 높은 경우**에 한해 권장됩니다.
# - **약관 조항 무효 확인 소송**:
#   - "시스템 오류 책임 전면 부인" 조항이 불공정약관에 해당한다면, 해당 조항의 무효를 주장하며 소송을 제기할 수 있습니다.
#
# #### 4. **주의사항**
# - **계정 공유의 법적 리스크**:
#   - 게임회사가 계정 공유를 금지하는 경우, 실소유주라도 법적 보호를 받기 어렵습니다(2006년 사례).
#   - 향후 계정 거래 시 **공식적인 양도 절차**(게임회사 승인)를 따르는 것이 안전합니다.
# - **시스템 오류의 객관적 입증**:
#   - 게임회사가 오류를 인정하지 않으면, **독립적인 기술적 감정**이 필요할 수 있습니다.
#
# #### 5. **제시된 사례집 외 추가 정보**
# - **게임 아이템의 재산권 인정 여부**:
#   - 현재 법원은 게임 아이템을 **채권적 청구권**으로 보며, 완전한 재산권으로 인정하지 않습니다(대법원 2010다88033 판결).
#   - 따라서 복구보다는 **손해배상** 형태로 해결될 가능성이 높습니다.
# - **집단 분쟁 가능성**:
#   - 동일 오류가 다수 이용자에게 발생한 경우, **집단소송** 또는 **소비자단체 소송**을 고려할 수 있습니다.
#
# ### 결론
# 시스템 오류로 인한 아이템 손실 시, **증거 확보 → 게임회사 협의 → 소비자원 조정 → 소송**의 단계적 접근이 필요합니다. 다만, 계정 공유나 시스템 오류 입증 실패 시 복구가 어려울 수 있으므로, 사전에 게임회사의 약관을 꼼꼼히 확인하고 안전한 계정 관리를 하는 것이 중요합니다.
#
# > ※ 본 답변은 제시된 사례 및 현행 법령을 기반으로 작성되었으며, 구체적인 사안은 전문 법률가와 상담이 필요합니다.
#
# [참조 출처]
#   - 1) page=8, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 2) page=8, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 3) page=28, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 4) page=28, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 5) page=2, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#
# ================================================================================
# [Q2] 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#
# [답변]
#  ### 전문 법률 조언: 인터넷 강의 중도 해지 시 과도한 위약금 요구의 적법성 검토
#
# #### 1. **사례 분석 및 법적 근거**
# 제시된 사례(2007_인터넷교육서비스 중도해지 요구, 2007_온라인통신교육서비스 대금 환급 요구2 등)에 따르면, **온라인 교육 서비스 중도 해지 시 위약금 공제**는 다음과 같은 원칙에 따라 판단됩니다.
#
# - **소비자분쟁해결기준(공정위 고시, 인터넷콘텐츠업)**
#   - 해지일까지의 **이용일수**에 해당하는 금액과 **총 이용금액의 10%**를 공제한 후 환급해야 함.
#   - 사은품은 미사용 시 반환해야 하며, 반환되지 않은 경우 그 비용을 공제할 수 있음.
#   - 단, **계약서 미기재 항목**(예: 교재비, 회원가입비 등)은 공제 대상이 될 수 없음.
#
# - **방문판매 등에 관한 법률 제30조**
#   - 위약금이 **실제 손실을 현저히 초과**하거나, **공급된 서비스 대가를 초과**하여 환급 거부하는 경우 무효.
#   - 예: 계약서에 명시되지 않은 "화상교육비" 또는 "교재비"를 공제하는 것은 부당함(2007_인터넷교육서비스 중도해지 요구 사례 참조).
#
# - **소비자기본법 시행령 제10조**
#   - 환급금 산정 시 **계약서에 기재된 금액**을 기준으로 해야 하며, 구두 약정 또는 사후 추가 비용은 인정되지 않음.
#
# #### 2. **실무적 해결 방안**
# **(1) 계약서 확인**
# - 계약서에 **명시된 항목**(월 교육비, 계약 기간, 위약금 조건 등)을 확인합니다.
# - **미기재 항목**(예: 교재비, 가입비)이 공제되었다면 이는 부당할 수 있습니다.
#
# **(2) 이용 실적 증빙**
# - 해지 전까지 **실제 이용한 강의 횟수/기간**을 확인합니다.
# - 예: 1년 계약 중 3개월만 이용했다면, 나머지 9개월 분의 90% 환급 요구 가능(총 이용금액의 10% 공제 후).
#
# **(3) 사은품 처리**
# - 사은품을 반환하지 않은 경우, 그 비용을 공제할 수 있으나, **반환 가능성**을 검토합니다.
# - 예: 미개봉 사은품은 반환하여 공제 항목에서 제외 요청.
#
# **(4) 과도한 위약금 이의 제기**
# - 위약금이 **총 이용금액의 10%를 초과**하거나, **실제 이용 기간 대비 불합리**하다면 한국소비자원에 분쟁 조정을 신청할 수 있습니다.
# - 사례 참조: 2007_온라인통신교육서비스 대금 환급 요구2에서 피청구인이 교재비 등을 공제한 것은 계약서 미기재로 인해 부당하다고 판단됨.
#
# **(5) 법적 조치**
# - 사업자가 조정을 거부할 경우, **소비자기본법 제18조**에 따라 소비자분쟁조정위원회에 조정 신청하거나, **민사소송**을 제기할 수 있습니다.
#
# #### 3. **주의사항**
# - **구두 해지 통보**는 증거 부재로 인해 효력이 약할 수 있으므로, **이메일 또는 내용증명**으로 해지 의사를 명확히 전달해야 합니다(2007_인터넷교육서비스 중도해지 요구 사례에서 청구인의 구두 해지 통보가 후속 접속 기록으로 인해 효력이 약화된 사례 참조).
# - **제시된 사례집에는 없는 내용**(예: 코로나19로 인한 특별 해지권, 장애인 할인 환급 등)은 본 답변에서 다루지 않았습니다.
#
# #### 4. **결론**
# 과도한 위약금 요구는 **소비자분쟁해결기준 및 방문판매법 위반**일 가능성이 높습니다. 계약서 상의 공제 항목과 실제 이용 내역을 비교하여 **10% 초과분 또는 미기재 항목**에 대해서는 환급을 요구할 수 있으며, 사업자와의 협의가 어려울 경우 **한국소비자원 또는 법적 절차**를 활용하는 것이 권장됩니다.
#
# > ✅ **요약**:
# > - **계약서 미기재 항목** 공제 불가.
# > - **이용일수 + 총금액의 10%**만 공제 가능.
# > - 사은품은 반환 시 공제 제외.
# > - 분쟁 시 **소비자분쟁조정위원회**에 조정 신청.
#
# [참조 출처]
#   - 1) page=3, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 2) page=3, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 3) page=62, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 4) page=62, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 5) page=60, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#
# ================================================================================
# [Q3] 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#
# [답변]
#  ### 전문 법률 조언: 무료체험 후 자동 유료전환 및 환불 요건 분석
#
# #### 1. **사례 근거 및 쟁점 분석**
# 제시된 사례(한국소비자원 2010년 조정결정례, 전자거래분쟁조정위원회 2006년 사례)에 따르면, **무료체험 후 자동 유료전환**으로 인한 분쟁은 다음과 같은 쟁점으로 판단됩니다:
# - **중요사항 고지의무 위반 여부**: 사업자가 "무료체험 기간 내 해지하지 않을 경우 유료전환" 사실을 명확히 고지했는지 여부.
# - **소비자의 인지 가능성**: 고지 내용이 활자 크기, 위치, 반복성 등에서 소비자가 쉽게 인지할 수 있었는지.
# - **소비자의 과실 유무**: 이용약관에 동의하거나 장기간 이의 없이 결제한 경우 책임 분배.
#
# #### 2. **관련 법령**
# - **약관의 규제에 관한 법률 제3조(약관 작성 및 설명의무)**:
#   사업자는 계약 체결 시 **중요한 내용**(유료전환 조건 등)을 소비자가 이해할 수 있도록 명시·설명해야 합니다.
#   - 위반 시 해당 약관 조항은 무효이며, 소비자는 계약 취소 또는 손해배상을 청구할 수 있습니다.
# - **소비자기본법 제18조(소비자분쟁해결기준)**:
#   사업자의 고지의무 위반 시 **전액 또는 부분 환불**이 가능합니다.
#   - 예시: 한국소비자원 사례에서는 사업자의 책임을 50%로 제한해 부분 환급을 결정했습니다.
#
# #### 3. **유사 사례 처리 결과**
# - **한국소비자원 사례(2010년)**:
#   - 사업자가 이벤트 화면에 유료전환 사실을 고지했으나, **활자 크기가 작아 인지하기 어려웠음**을 이유로 **50% 책임**을 인정.
#   - 소비자가 4개월간 이의 없이 결제한 점을 고려해 **부분 환급(50%)** 결정.
# - **전자거래분쟁조정위원회 사례(2006년)**:
#   - 무료 광고로 유인한 후 유료전환을 명확히 고지하지 않아 **사업자 책임** 인정.
#   - 표시광고법 및 약관규제법 위반 가능성으로 시정 권고.
#
# #### 4. **실무적 해결방안 (단계별)**
# **(1) 증거 수집**
# - 무료체험 가입 시 **고지 내용**(화면 캡처, 이용약관)을 확보합니다.
# - 유료전환 통지 여부(문자, 이메일 등) 및 **결제 내역**을 확인합니다.
#
# **(2) 사업자와의 직접 협상**
# - **전액 환불**을 요구하되, 사업자가 부분 책임을 주장할 경우 **50% 환급**을 제안합니다.
# - 한국소비자원 사례에서와 같이 **장기간 결제 시 소비자 과실**이 인정될 수 있음을 고려합니다.
#
# **(3) 분쟁조정 신청**
# - 협상 실패 시 **한국소비자원** 또는 **전자거래분쟁조정위원회**에 조정을 신청합니다.
# - 조정 시 **고지 불충분성**과 **소비자 피해**를 강조해 부분 환급 이상의 결과를 요구합니다.
#
# **(4) 소송 제기 (최후 수단)**
# - 조정 결과가 불만족스러울 경우, **민사소송**을 통해 계약 취소 또는 손해배상을 청구할 수 있습니다.
# - 단, **소송 비용**과 **입증 책임**을 고려해야 합니다.
#
# #### 5. **주의사항**
# - **이용약관 동의 여부**: 약관에 유료전환 조건이 포함되어 있고 소비자가 동의한 경우, 책임이 감소할 수 있습니다.
# - **소비자 과실**: 장기간 결제 후 이의를 제기하지 않으면 **과실 상계**가 적용될 수 있습니다(한국소비자원 사례 참조).
# - **제시된 사례집 외 내용**:
#   - "무료체험 기간 연장" 또는 "자동갱신 해지 방법 미제공"과 같은 추가 쟁점은 본 사례집에서 확인할 수 없습니다.
#
# #### 6. **결론**
# - **환불 가능성**은 사업자의 **고지 충분성**과 소비자의 **과실 유무**에 따라 달라집니다.
# - 부분 환급(30~50%)을 목표로 협상하되, 고지가 현저히 불명확한 경우 전액 환불을 주장할 수 있습니다.
# - 분쟁조정 기관을 활용해 **법적 효력** 있는 해결을 권장합니다.
#
# > ✅ **추천 조치**: 한국소비자원에 조정 신청 시, **고지 화면 캡처**와 **결제 내역**을 첨부해 신속히 대응하시기 바랍니다.
#
# [참조 출처]
#   - 1) page=100, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 2) page=100, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 3) page=101, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 4) page=101, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 5) page=102, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#
# ================================================================================
# [Q4] 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#
# [답변]
#  ### 전문 법률 조언: 미성년자 부모 동의 없이 게임 아이템 구매 시 환불 가능성
#
# #### 1. **사례 및 법령 근거 분석**
# 제시된 사례(2008_부당결제대금 반환 청구, 2006_미성년자 단독 결제 취소 청구)와 관련 법령을 종합하면 다음과 같은 법리가 적용됩니다.
#
# - **민법 제5조(미성년자의 능력)**: 미성년자가 법정대리인의 동의 없이 체결한 계약은 취소할 수 있습니다.
# - **민법 제741조(부당이득)**: 계약 무효 시 피신청인(게임사)은 정당한 이유 없이 취득한 대금을 반환해야 합니다.
# - **민법 제755조(감독자 책임)**: 미성년자의 불법행위에 대해 감독자(부모)가 책임을 질 수 있으나, 게임사의 과실도 고려됩니다.
#
# #### 2. **환불 가능성 판단 기준**
# **(1) 계약 당사자 및 동의 여부**
# - 미성년자가 **타인 명의를 도용**하거나 **성인 아이디로 결제**한 경우, 게임사는 "사술(詐術)"로 간주하여 계약 무효를 주장할 수 있습니다(2006년 사례 참조).
# - 단, **미성년자 본인 명의로 결제**하고 부모 동의가 없었다면, 계약은 취소 가능하며 환불 대상입니다(2008년 사례 참조).
#
# **(2) 게임사의 과실**
# - 게임사가 **실명 인증 절차를 소홀히 하거나**, 미성년자 결제 시 부모 동의를 확인하지 않은 경우, 일부 책임을 부담합니다(2008년 사례에서 게임사 35% 책임 인정).
#
# #### 3. **실무적 해결 방안**
# **(1) 1단계: 결제 내역 및 계약 당사자 확인**
# - **미성년자 본인 명의**로 결제되었는지, **타인 명의 도용** 여부를 확인합니다.
#   - 타인 명의 도용 시: 게임사는 환불을 거부할 수 있으나, 감독자(부모)의 책임을 추가로 검토해야 합니다.
#   - 미성년자 본인 명의 시: 부모 동의 없음을 입증하여 계약 취소를 요청할 수 있습니다.
#
# **(2) 2단계: 게임사에 환불 요청**
# - **전자거래분쟁조정위원회**에 조정을 신청하거나, 게임사의 고객센터에 다음 내용을 명시하여 요청합니다.
#   - "미성년자가 부모 동의 없이 체결한 계약이므로 민법 제5조에 따라 취소합니다."
#   - "게임사가 미성년자 결제 시 부모 동의를 확인하지 않은 과실이 있습니다."
#
# **(3) 3단계: 손해 분담 협상**
# - 2008년 사례와 같이 **게임사와 부모가 책임을 분담**하는 방식으로 합의할 수 있습니다.
#   - 예: 게임사가 30~40%, 부모가 60~70% 부담 (단, 게임사의 시스템 미비 증명이 필요).
#
# **(4) 4단계: 법적 조치**
# - 조정 실패 시 **민사소송**을 제기할 수 있으나, 미성년자의 불법 행위(명의 도용)가 증명되면 부모의 배상 책임이 발생할 수 있습니다.
#
# #### 4. **주의사항**
# - **제시된 사례집에는 없는 내용**:
#   - 신용카드 결제 시 「전자금융거래법」상 취소 권한, 「청소년 보호법」상 게임 결제 제한 규정 등은 추가 검토가 필요합니다.
#   - 게임사의 이용약관에서 "미성년자 결제 무효" 조항이 있는지 확인해야 합니다.
#
# #### 5. **결론**
# - **환불 가능성**은 계약 당사자(본인 명의 vs. 타인 명의)와 게임사의 과실(실명 인증 미비)에 따라 달라집니다.
# - **최적의 전략**: 전자거래분쟁조정위원회에 조정을 신청하여 게임사와 책임 분담을 협상하는 것이 효율적입니다.
#
# > ✅ **추천 조치**:
# > 1. 결제 수단(본인 명의/타인 명의) 및 게임사 시스템(실명 인증 여부) 확인 →
# > 2. 게임사에 계약 취소 및 환불 요청 →
# > 3. 거부 시 전자거래분쟁조정위원회 조정 신청 →
# > 4. 필요 시 소송 진행 (단, 명의 도용 시 부모 책임 리스크 고려).
#
# [참조 출처]
#   - 1) page=50, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 2) page=50, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 3) page=43, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 4) page=43, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 5) page=51, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#
# ================================================================================
# [Q5] 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#
# [답변]
#  ### 전문 법률 조언: 온라인 교육 서비스 계약 해지 및 환급 요건
#
# #### 1. **계약 해지 가능성 및 법적 근거**
# 제시된 사례(2010_온라인교육 서비스 계약 해지, 2008_온라인 통신교육서비스 이용료 환급 요구 등)에 따르면, **「방문판매 등에 관한 법률」** 제29조에 따라 소비자는 **계속적 거래 계약(1년 단위 온라인 교육 서비스 등)을 언제든지 해지할 권리**가 있습니다.
# - **계약 해지 요건**:
#   - 서비스 제공 내용이 광고와 현저히 다르거나, 기술적 문제(화상 불량, 동영상 서비스 중단 등)로 이용 불가능한 경우, 소비자는 **귀책사유 없이 해지**할 수 있습니다(사례 2010_화상불량으로 중도 해지한 인터넷강의 환급 요구 참조).
#   - 단, 단순 변심만으로는 해지 가능하나, **이용 기간에 따른 환급금 산정**이 적용됩니다.
#
# #### 2. **환급금 산정 기준**
# - **법적 기준**:
#   - 「방문판매 등에 관한 법률」 제30조는 **"소비자에게 발생한 손실을 현저히 초과하는 위약금을 청구할 수 없다"**고 규정합니다.
#   - 「소비자분쟁해결기준」(공정거래위원회 고시, 인터넷콘텐츠업)에 따라 **이용 기간(경과 일수)에 비례해 환급**해야 하며, **할인금액·부가비용 등은 공제 대상에서 제외**됩니다(사례 2008_온라인 통신교육서비스 이용료 환급 요구 참조).
#     - 예시: 1년 계약(12개월) 중 1개월 이용 후 해지 시, **11/12에 해당하는 금액 환급**이 원칙입니다.
#   - 사업자가 **"투입 비용"을 이유로 과도한 금액을 공제하는 것은 부당**합니다(사례 2010_온라인교육 서비스 계약 해지 참조).
#
# #### 3. **실무적 해결 단계**
# **(1) 계약 해지 통보**
# - 서면(이메일, 내용증명)으로 **해지 의사 + 광고와 다른 점/서비스 결함 증명 자료**를 첨부해 사업자에게 통보합니다.
#   - *예시*: "광고된 강의 콘텐츠와 실제 제공 내용이 상이하며, 동영상 재생 오류로 이용이 불가능합니다."
#
# **(2) 환급금 계산 요청**
# - 「소비자분쟁해결기준」에 따른 환급금(잔여 기간 비율)을 명시하고, **할인금액·부가세 등은 공제하지 않을 것**을 요구합니다.
#   - *예시*: "총 이용료 60만 원 중 1개월(1/12) 이용했으므로, 55만 원(60만 원 × 11/12) 환급 요청합니다."
#
# **(3) 분쟁 조정 신청**
# - 사업자가 불합리한 환급금을 제시할 경우, **한국소비자원에 분쟁 조정**을 신청합니다.
#   - *사례 참조*: 2010년 사례에서 사업자는 1/3만 환급하려 했으나, 조정 결과 **잔여 기간 전액 환급**이 결정되었습니다.
#
# #### 4. **주의사항**
# - **증거 확보**: 광고 자료, 이용 내역, 서비스 결함 기록(스크린샷, 오류 메시지)을 보관합니다.
# - **계약 조건 확인**: 약관에 "해지 시 위약금 00% 부과" 등의 조항이 있더라도, 「방문판매법」 제45조(소비자 불리한 계약 금지)에 따라 **무효일 수 있습니다**.
#
# #### 5. **사례집에 없는 내용**
# - "교육 서비스 품질 저하로 인한 해지 시 추가 배상금 청구"는 제시된 사례에서 확인되지 않습니다.
#
# ### 결론
# **광고와 다른 서비스 제공 또는 기술적 결함으로 인한 해지는 법적으로 가능하며, 잔여 이용 기간에 따른 환급금을 요구할 수 있습니다.** 사업자가 불합리한 공제를 주장할 경우, 한국소비자원의 분쟁 조정 절차를 활용하는 것이 효과적입니다.
#
# [참조 출처]
#   - 1) page=3, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 2) page=3, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 3) page=74, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 4) page=74, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
#   - 5) page=64, source=C:\mylangchain\mylangchain-app\src\mylangchain_app\data\콘텐츠분쟁해결_사례.pdf
